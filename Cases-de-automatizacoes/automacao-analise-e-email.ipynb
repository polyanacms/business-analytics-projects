# %%
# 1: Entrar no sistema da empresa
import pyautogui
import time
pyautogui.PAUSE = 1
pyautogui.press('win')
pyautogui.write('chrome')
pyautogui.press('enter')
time.sleep(1)
pyautogui.click(x=777, y=579) #clicar no usuário google
link_sistema = 'https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga'
pyautogui.write(link_sistema)
pyautogui.press('enter')

# 2: Navegar no sistema para encontrar a base de dados
time.sleep(5)
pyautogui.click(x=510, y=345,clicks=2) # seleciona o arquivo
time.sleep(3)
pyautogui.click(x=1838, y=355) # clica nos 3 ponto
pyautogui.click(x=1660, y=429) # baixa o arquivo

# 4: Calcular os indicadores (faturamento e quantidade de produos vendidos)

import pandas
caminho = r'C:\Users\user\Downloads\Vendas - Dez.xlsx'
tabela = pandas.read_excel(caminho)
display(tabela) 

faturamento = tabela['Valor Final'].sum()
qtde_produtos = tabela['Quantidade'].count()
print(faturamento)
print(qtde_produtos)


# 5: Enviar as informações por e-mail

import pyperclip
time.sleep(5)
pyautogui.hotkey('ctrl','t')
pyautogui.write('http://mail.google.com/')
pyautogui.press('enter')
time.sleep(3)
pyautogui.click(x=69, y=219)
time.sleep(1)

pyautogui.write('pollyanna_cristina07@yahoo.com')
pyautogui.press('tab') # selecionar email
pyautogui.press('tab') # ir para campo assunto
pyperclip.copy('Relatório de vendas - teste python')
pyautogui.hotkey('ctrl','v')
pyautogui.press('tab') # ir para corpo de e-mail

texto_email = f"""
Prezados,

Segue o relatório de vendas de hoje.

Faturamento: R$ {faturamento:,.2f}
Quantidade de produtos vendidos: {qtde_produtos:,}

Qualquer dúvida estou a disposição

Abraços,
Polyana Silva
"""
pyperclip.copy(texto_email)
pyautogui.hotkey("ctrl", "v")
time.sleep(2)
#enviar e-mail
pyautogui.click(x=1311, y=1000)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
time.sleep(5)
print(pyautogui.position())
# Out:
# Point(x=1311, y=1000)
